# %%
# ELECTRA SUICIDAL TEXT DETECTOR — TESTING NOTEBOOK


import torch
from transformers import ElectraForSequenceClassification, ElectraTokenizer
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')


# CONNECT GOOGLE DRIVE

from google.colab import drive
drive.mount('/content/drive')


# LOAD SAVED MODEL & TOKENIZER
print("=" * 90)
print("🔹 LOADING ELECTRA MODEL FROM DRIVE")
print("=" * 90)

model_dir = "/content/drive/MyDrive/electra_suicidal_text_detector"

if os.path.exists(model_dir):
    print(f"\n✓ Model directory found: {model_dir}")
    print("✓ Files in directory:")
    for file in os.listdir(model_dir):
        print(f"  - {file}")
else:
    raise FileNotFoundError(f"✗ ERROR: Model directory not found at {model_dir}")

# Load tokenizer and model
tokenizer = ElectraTokenizer.from_pretrained(model_dir, local_files_only=True)
model = ElectraForSequenceClassification.from_pretrained(model_dir, local_files_only=True)

# Device setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.eval()

# Label encoder for decoding predictions
label_encoder = LabelEncoder()
label_encoder.fit(['non-suicide', 'suicide'])

print("\n✅ Model and tokenizer loaded successfully!")
print(f"Device: {device}")
print("=" * 90)



# PREDICTION FUNCTION
def predict_suicidal_text(text):
    """Predict if text contains suicidal intent"""
    encoding = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=128,
        return_token_type_ids=False,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )

    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        probs = torch.softmax(logits, dim=1)
        prediction = torch.argmax(probs, dim=1)

    class_name = label_encoder.inverse_transform(prediction.cpu().numpy())[0]
    confidence = probs[0][prediction.item()].item()

    return {
        'text': text,
        'prediction': class_name,
        'confidence': confidence,
        'probabilities': {
            'non-suicidal': probs[0][0].item(),
            'suicidal': probs[0][1].item()
        }
    }



# BATCH PREDICTION ON SAMPLE TEXTS
print("\n🔹 TESTING MODEL ON SAMPLE TEXTS\n")

sample_texts = [
    "I am done with this life, I can't take it anymore.",
    "I feel good today, finally getting things done.",
    "I can't take this pain anymore, nobody cares about me.",
    "It's a beautiful day outside, I love my family.",
    "i want to jump off the building",
    "i can't keep doing this much longer",
    "I dont see the point of living anymore",
    "I don't want to live anymore, everything feels pointless.",
    "I'm thinking about ending my life tonight, I can't handle the pain."
]

results = []
for i, text in enumerate(sample_texts, 1):
    result = predict_suicidal_text(text)
    results.append(result)
    print(f"\n{'─'*80}")
    print(f"Example {i}:")
    print(f"Text: {result['text']}")
    print(f"Prediction: {result['prediction'].upper()} ({result['confidence']:.2%})")
    print(f"→ Non-Suicidal: {result['probabilities']['non-suicidal']:.4f}")
    print(f"→ Suicidal: {result['probabilities']['suicidal']:.4f}")

# Summary table
summary_df = pd.DataFrame([
    {
        'Text': r['text'][:60] + ('...' if len(r['text']) > 60 else ''),
        'Prediction': r['prediction'].upper(),
        'Confidence': f"{r['confidence']:.2%}",
        'Non-Suicidal': f"{r['probabilities']['non-suicidal']:.4f}",
        'Suicidal': f"{r['probabilities']['suicidal']:.4f}"
    }
    for r in results
])

print("\n\n" + "="*90)
print("🔹 BATCH PREDICTIONS SUMMARY")
print("="*90)
print(summary_df.to_string(index=False))

# # Save results to CSV
# summary_df.to_csv("batch_predictions.csv", index=False)
# print("\n✓ Predictions saved to 'batch_predictions.csv'")

# INTERACTIVE USER INPUT PREDICTION
print("\n" + "="*90)
print("🔹 INTERACTIVE USER INPUT PREDICTION")
print("="*90)
print("Type your own sentence (or 'quit' to exit):\n")

while True:
    user_input = input("Enter text: ").strip()
    if user_input.lower() == 'quit':
        print("Exiting... 👋")
        break
    if not user_input:
        print("⚠️ Please type something!")
        continue

    result = predict_suicidal_text(user_input)
    print("\n" + "-"*80)
    print(f"Prediction: {result['prediction'].upper()} ({result['confidence']:.2%})")
    print(f"→ Non-Suicidal: {result['probabilities']['non-suicidal']:.4f}")
    print(f"→ Suicidal: {result['probabilities']['suicidal']:.4f}")
    print("-"*80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ==========================================================================================
# 🔹 LOADING ELECTRA MODEL FROM DRIVE
# ==========================================================================================
#
# ✓ Model directory found: /content/drive/MyDrive/electra_suicidal_text_detector
# ✓ Files in directory:
#   - config.json
#   - model.safetensors
#   - special_tokens_map.json
#   - tokenizer_config.json
#   - vocab.txt
#
# ✅ Model and tokenizer loaded successfully!
# Device: cpu
# ==========================================================================================
#
# 🔹 TESTING MODEL ON SAMPLE TEXTS
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 1:
# Text: I am done with this life, I can’t take it anymore.
# Prediction: SUICIDE (60.04%)
# → Non-Suicidal: 0.3996
# → Suicidal: 0.6004
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 2:
# Text: I feel good today, finally getting things done.
# Prediction: NON-SUICIDE (99.24%)
# → Non-Suicidal: 0.9924
# → Suicidal: 0.0076
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 3:
# Text: I can't take this pain anymore, nobody cares about me.
# Prediction: NON-SUICIDE (61.58%)
# → Non-Suicidal: 0.6158
# → Suicidal: 0.3842
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 4:
# Text: It’s a beautiful day outside, I love my family.
# Prediction: NON-SUICIDE (99.43%)
# → Non-Suicidal: 0.9943
# → Suicidal: 0.0057
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 5:
# Text: i want to jump off the building
# Prediction: SUICIDE (71.31%)
# → Non-Suicidal: 0.2869
# → Suicidal: 0.7131
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 6:
# Text: i can't keep doing this much longer
# Prediction: SUICIDE (67.47%)
# → Non-Suicidal: 0.3253
# → Suicidal: 0.6747
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 7:
# Text: I dont see the point of living anymore
# Prediction: SUICIDE (77.99%)
# → Non-Suicidal: 0.2201
# → Suicidal: 0.7799
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 8:
# Text: I don’t want to live anymore, everything feels pointless.
# Prediction: NON-SUICIDE (54.95%)
# → Non-Suicidal: 0.5495
# → Suicidal: 0.4505
#
# ────────────────────────────────────────────────────────────────────────────────
# Example 9:
# Text: I’m thinking about ending my life tonight, I can’t handle the pain.
# Prediction: SUICIDE (61.80%)
# → Non-Suicidal: 0.3820
# → Suicidal: 0.6180
#
#
# ==========================================================================================
# 🔹 BATCH PREDICTIONS SUMMARY
# ==========================================================================================
#                                                            Text  Prediction Confidence Non-Suicidal Suicidal
#              I am done with this life, I can’t take it anymore.     SUICIDE     60.04%       0.3996   0.6004
#                 I feel good today, finally getting things done. NON-SUICIDE     99.24%       0.9924   0.0076
#          I can't take this pain anymore, nobody cares about me. NON-SUICIDE     61.58%       0.6158   0.3842
#                 It’s a beautiful day outside, I love my family. NON-SUICIDE     99.43%       0.9943   0.0057
#                                 i want to jump off the building     SUICIDE     71.31%       0.2869   0.7131
#                             i can't keep doing this much longer     SUICIDE     67.47%       0.3253   0.6747
#                          I dont see the point of living anymore     SUICIDE     77.99%       0.2201   0.7799
#       I don’t want to live anymore, everything feels pointless. NON-SUICIDE     54.95%       0.5495   0.4505
# I’m thinking about ending my life tonight, I can’t handle th...     SUICIDE     61.80%       0.3820   0.6180
#
# ==========================================================================================
# 🔹 INTERACTIVE USER INPUT PREDICTION
# ==========================================================================================
# Type your own sentence (or 'quit' to exit):
#
# Enter text: life has no purose ,  i want to end this
#
# --------------------------------------------------------------------------------
# Prediction: SUICIDE (77.28%)
# → Non-Suicidal: 0.2272
# → Suicidal: 0.7728
# --------------------------------------------------------------------------------
# Enter text: quit
# Exiting... 👋
